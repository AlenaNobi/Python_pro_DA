# %%
msg = "Welcome to Notebooks in VS Code!"
print(msg)
# Out:
# Welcome to Notebooks in VS Code!

# %%
msg = "Těším se na kurz datové analýzy v Pythonu!"
print(msg)
# Out:
# Těším se na kurz datové analýzy v Pythonu!

# %%
import pandas

# %%
food = pandas.read_csv("food_sample_100.csv")

# %%
food
# Out:
#      fdc_id           data_type  \
# 0   2644829     sub_sample_food
# 1   2347263     sub_sample_food
# 2   2261954     sub_sample_food
# 3    321470     sub_sample_food
# 4    322951     sub_sample_food
# ..      ...                 ...
# 95  2260615     sub_sample_food
# 96  2646468     sub_sample_food
# 97  2647032     sub_sample_food
# 98  2349564     sub_sample_food
# 99   328565  market_acquisition
#
#                                           description  food_category_id  \
# 0                                        lentils, dry              16.0
# 1                                         heavy cream               1.0
# 2                                       Flour, potato              11.0
# 3                                       Salt, Iodized               2.0
# 4                                       Hot dogs beef               7.0
# ..                                                ...               ...
# ...

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fdc_id            100 non-null    int64
#  1   data_type         100 non-null    object
#  2   description       100 non-null    object
#  3   food_category_id  99 non-null     float64
#  4   publication_date  100 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
food.head(10)
# Out:
#     fdc_id           data_type  \
# 0  2644829     sub_sample_food
# 1  2347263     sub_sample_food
# 2  2261954     sub_sample_food
# 3   321470     sub_sample_food
# 4   322951     sub_sample_food
# 5  2346484         sample_food
# 6   330060  market_acquisition
# 7  1754088     sub_sample_food
# 8  2346855  market_acquisition
# 9  2351012     sub_sample_food
#
#                                          description  food_category_id  \
# 0                                       lentils, dry              16.0
# 1                                        heavy cream               1.0
# 2                                      Flour, potato              11.0
# 3                                      Salt, Iodized               2.0
# 4                                      Hot dogs beef               7.0
# 5                              Lettuce, iceberg, raw              11.0
# 6  Greek yogurt, FAGE PLAIN NONFAT (CA2) - NFY0910IC               1.0
# ...

# %%
food.tail()
# Out:
#      fdc_id           data_type  \
# 95  2260615     sub_sample_food
# 96  2646468     sub_sample_food
# 97  2647032     sub_sample_food
# 98  2349564     sub_sample_food
# 99   328565  market_acquisition
#
#                                           description  food_category_id  \
# 95                          Yogurt, whole milk, plain               1.0
# 96                chicken, breast, boneless, skinless               5.0
# 97                               pork, loin, boneless              10.0
# 98           Oats, whole grain, rolled, old fashioned              20.0
# 99  Cheese, cheddar, mild, block/chunk, store bran...               1.0
#
#    publication_date
# 95       2022-04-28
# 96       2023-10-19
# 97       2023-10-19
# 98       2022-10-28
# 99       2019-04-01

# %%
food.sample(20)
# Out:
#      fdc_id           data_type  \
# 2   2261954     sub_sample_food
# 16  1752357     sub_sample_food
# 18  2004374     sub_sample_food
# 64   333389     sub_sample_food
# 5   2346484         sample_food
# 29  2348279     sub_sample_food
# 48  2259344     sub_sample_food
# 78  2646778     sub_sample_food
# 17  2514917     sub_sample_food
# 25  2351006     sub_sample_food
# 47   327076     sub_sample_food
# 10  2004036     sub_sample_food
# 0   2644829     sub_sample_food
# 23  2003754         sample_food
# 3    321470     sub_sample_food
# 21  2349948     sub_sample_food
# 84  2351685     sub_sample_food
# 61  2003818         sample_food
# 67   327756     sub_sample_food
# 66   332636  market_acquisition
#
#                                           description  food_category_id  \
# 2                                       Flour, potato              11.0
# 16      ALMOND MILK, UNSWEETENED, PLAIN, SHELF STABLE              14.0
# ...

# %%
food.shape[1]
# Out:
# 5

# %%
food.columns
# Out:
# Index(['fdc_id', 'data_type', 'description', 'food_category_id',
#        'publication_date'],
#       dtype='object')

# %%
food["description"]
food[["description"]]
# Out:
#                                           description
# 0                                        lentils, dry
# 1                                         heavy cream
# 2                                       Flour, potato
# 3                                       Salt, Iodized
# 4                                       Hot dogs beef
# ..                                                ...
# 95                          Yogurt, whole milk, plain
# 96                chicken, breast, boneless, skinless
# 97                               pork, loin, boneless
# 98           Oats, whole grain, rolled, old fashioned
# 99  Cheese, cheddar, mild, block/chunk, store bran...
#
# [100 rows x 1 columns]

# %%
food.iloc[5]
food.iloc[[5]]
# Out:
#     fdc_id    data_type            description  food_category_id  \
# 5  2346484  sample_food  Lettuce, iceberg, raw              11.0
#
#   publication_date
# 5       2022-10-28
