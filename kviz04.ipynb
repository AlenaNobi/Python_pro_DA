# %%
import pandas as pd

# %%
data = pd.read_csv("penguins.txt")
data
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
bins = [0, 180, 200, float('inf')]
labels = ['short', 'medium', 'long']

data['flipper_length_category'] = pd.cut(data['flipper_length_mm'], bins=bins, labels=labels)
data
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year flipper_length_category
# ...

# %%
(data['flipper_length_category'] == 'long').sum()
# Out:
# np.int64(148)

# %%
pd.crosstab(data["species"], data["island"])
# Out:
# island     Biscoe  Dream  Torgersen
# species
# Adelie         44     56         52
# Chinstrap       0     68          0
# Gentoo        124      0          0

# %%
pd.crosstab(data["species"], data["island"], normalize="index")
# Out:
# island       Biscoe     Dream  Torgersen
# species
# Adelie     0.289474  0.368421   0.342105
# Chinstrap  0.000000  1.000000   0.000000
# Gentoo     1.000000  0.000000   0.000000

# %%
pd.crosstab(index=data["species"], columns=data["sex"], values=data["bill_depth_mm"], aggfunc="mean")
# Out:
# sex           female       male
# species
# Adelie     17.621918  19.072603
# Chinstrap  17.588235  19.252941
# Gentoo     14.237931  15.718033
